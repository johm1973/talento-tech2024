# %% [markdown]
# <a href="https://colab.research.google.com/github/johm1973/talento-tech2024/blob/main/2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# JOHN VANEGAS 27/05/2024

# %%
# Import libraries
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Create a dataset
# Let´s build the values lists
value_a_list = ['Carcasa', 'Filtro', 'Manguera','Ventury','Cable','Camara', 'Fusible', 'Botones','Valvula','Caja']
print(value_a_list)

value_b_list = [15,25,24,89,57,62,31,91,56,84]
value_c_list = [10000,8000,3000,2500,6800,9300,4500,8000,14000,4500]
value_d_list = [50,45,23,15,100,250,325,89,56,352]
value_e_list = [150,250,124,352,568,204,362,892,635,247]
#print(value_e_list)
value_bmi_list = df['bmi'] = df['valor'] * df['salidas']* df['stock']
value_BMI_list = df['BMI'] = df['valor'] * df['entradas']
value_x_list = df['x'] = df['ganancias'] - df['gastos']

# Let´s use a dictionary ({key:value})
# with the format {"str":list}
data_dict = {
             "producto":value_a_list,
             "stock":value_b_list,
             "valor":value_c_list,
             "salidas":value_d_list ,
              "entradas":value_e_list,
             "ganancias":value_bmi_list,
              "gastos":value_BMI_list,
             "total":value_x_list
              }

# Turn a dictionary into a dataframe
df = pd.DataFrame(data_dict)

print(df)
# Call a variable
df
# Out:
# ['Carcasa', 'Filtro', 'Manguera', 'Ventury', 'Cable', 'Camara', 'Fusible', 'Botones', 'Valvula', 'Caja']
#    producto  stock  valor  salidas  entradas  ganancias   gastos      total
# 0   Carcasa     15  10000       50       150    7500000  1500000    6000000
# 1    Filtro     25   8000       45       250    9000000  2000000    7000000
# 2  Manguera     24   3000       23       124    1656000   372000    1284000
# 3   Ventury     89   2500       15       352    3337500   880000    2457500
# 4     Cable     57   6800      100       568   38760000  3862400   34897600
# 5    Camara     62   9300      250       204  144150000  1897200  142252800
# 6   Fusible     31   4500      325       362   45337500  1629000   43708500
# 7   Botones     91   8000       89       892   64792000  7136000   57656000
# 8   Valvula     56  14000       56       635   43904000  8890000   35014000
# 9      Caja     84   4500      352       247  133056000  1111500  131944500
# ...
