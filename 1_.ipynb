# %% [markdown]
# <a href="https://colab.research.google.com/github/johm1973/talento-tech2024/blob/main/1_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import math
import numpy as np
#import pandas as pd
import matplotlib.pyplot as plt

#print("hola-mundo.py")
c = math.sqrt(2)

x = np.linspace(-10*math.pi, 10*math.pi,500)
y = np.cos(x)

plt.plot(x,y)
plt.title("y=cos(x)")
plt.xlabel('x')
plt.ylabel('y')
plt.grid()
plt.show()
